# %%
import pickle

saved_clusters = 'model/clustering_results/cluster/latest_clusters.pkl'
with open(saved_clusters, 'rb') as f:
    cached_data = pickle.load(f)

# %%
cached_data
# Out:
# {'cluster_to_games': {0: ['Caesar & Cleopatra',
#    'Enemy in Sight',
#    'Plague & Pestilence',
#    'The Big Idea',
#    'Nuclear War',
#    'Witch Trial',
#    'Venture',
#    'Star Force Terra #1: Contact!',
#    'BANG!',
#    'Lifeboat',
#    "Queen's Necklace",
#    'Zauberschwert & Drachenei',
#    'Station Master'],
#   1: ['Klunker',
#    'Guillotine',
#    'Twitch',
#    'High Society',
#    'Campanile',
#    'Cat Blues',
#    'The Bottle Imp',
#    'Hera and Zeus',
#    'Chrononauts',
#    'Chronology',
#    'Four Dragons',
#    'Oh Hell!',
#    'Serengeti',
#    'Turn the Tide',
#    'Girl Genius: The Works',
#    'Portal',
#    'Foppen',
#    'Bali',
#    'Vom Kap bis Kairo',
#    'Compatibility',
#    'Tarock',
#    'Camden',
#    'Cranium: Hoopla',
#    'Tarot',
#    'Eleusis',
#    'Schafkopf',
#    'Mus',
#    'Hearts',
#    'Emmerlaüs Duel of Mages',
#    'Sluff Off!',
#    'Corsari',
#    'Duell',
#    'Wings of War: Watch Your Back!'],
#   2: ['Mamma Mia!',
# ...

# %%
import polars as pl

df = pl.read_json("game_data.json")

# %%
import math 

def smooth_decreasing_function(x, k=1):
    if x < 1:
        raise ValueError("Input x must be greater than or equal to 1.")
    return 1 / (1 + math.exp(k * (x - 1)))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
